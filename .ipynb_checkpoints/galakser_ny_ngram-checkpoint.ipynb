# %% [markdown]
# # Galakser

# %%
# %%HTML
# <style>
# p {font-size:1.2em;
#   font-family: Georgia, serif};
# </style>
# Out:
# <style>
# p {font-size:1.2em;
#   font-family: Georgia, serif};
# </style>

# %%
import pandas as pd

# %%
bøker = pd.read_csv("../../ngram_2021_coordination/coord-bok.csv", header = None)

# %%
bøker.columns = ['lang', 'first', 'coord', 'second', 'freq']

# %%
bøker[bøker['first'] == '.'].head(2)
# Out:
#      lang first coord      second  freq
# 8927  nno     .    og        0,75     4
# 8928  nno     .    og  09.01.2010     4

# %%
"a".isalpha()
# Out:
# True

# %%
bøker_words = bøker[bøker['first'].map(lambda x: x.isalpha())][bøker['second'].map(lambda x: x.isalpha())]
# Out:
# /tmp/ipykernel_154307/342431437.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   bøker_words = bøker[bøker['first'].map(lambda x: x.isalpha())][bøker['second'].map(lambda x: x.isalpha())]

# %%
bøker_words
# Out:
#         lang  first coord    second     freq
# 15380    nno      A    og       Fig        4
# 15381    nno      A    og  Marianna        4
# 15382    nno      A    og        VB        4
# 15383    nno      A    og       alt        4
# 15384    nno      A    og     anten        4
# ...      ...    ...   ...       ...      ...
# 4752037  nob    mer    og       mer   593743
# 4752038  nob   rett    og     slett   597504
# 4752052  nob     av    og       til   984899
# 4752055  nob  først    og    fremst  1637971
# 4752056  nob    til    og       med  1664287
#
# [4084866 rows x 5 columns]

# %%
coord = bøker_words.groupby(['first', 'second']).sum()

# %%
from math import log, sqrt

# %%
#coord['weight'] = coord['freq']*coord['pmi']

# %% [markdown]
# In a position "$x\textrm{ and }y$" the part frequencies of $x$, $x_f$, are used in computing $\frac{p(y|x)}{p(y)}$. All proportions are computed from that particular position. So the what is computed
# is
#
# 1. $p(x) = \frac{x_f}{\sigma(x_f)}$ and
# 1. $p(y|x) = \frac{y_f^x}{\sigma(x_f)}$.
#
# Here $y_f^x$ is the the frequency of $y$ in the context $x$. The complete formula to be taken to pandas is then:
#
# $p(x|y) = \frac{x^y}{\sigma(y)}$
#
# $p(y) = \frac{\sigma(y)}{t}$

# %%
cond = lambda x, level = 0:(coord.xs(x, level = level)/coord.xs(x, level = level).sum())

# %%
summation = lambda x, level = 0: coord.xs(x, level = level).sum()

# %%
summation('Hamsun', 0)
# Out:
# freq    4756
# dtype: int64

# %%
triples = pd.DataFrame([(x, summation(x, 0)) for x in set(coord.index.get_level_values(level = 0))], columns = ['word', 'as_first'])

# %%
tuples_second = pd.DataFrame([(x, summation(x, 1)) for x in set(coord.index.get_level_values(level = 1))], columns = ['word', 'as_second'])

# %%
tuples_second = tuples_second.set_index('word')

# %%
tuples_second = tuples_second.fillna(0).applymap(int)

# %%
tuples_second.loc['i']
# Out:
# as_second    2809784
# Name: i, dtype: int64

# %%
totals_second = tuples_second.sum()
totals_second
# Out:
# as_second    231478939
# dtype: int64

# %%
#tuples_second.to_csv("second_position_frequencies.csv", header = True)

# %% [markdown]
# ## Fix values and such

# %%
galaxy_freqs = pd.concat([triples.set_index('word'), tuples_second.set_index('word')], axis = 1)

# %%
galaxy_freqs = galaxy_freqs.fillna(0).applymap(int)

# %%
#galaxy_freqs.to_csv('galaxy_frequencies.csv', header = True)

# %% [markdown]
# ## Compute pmi

# %%
galaxy_freqs.loc['spiser']
# Out:
# as_first     17552
# as_second    42501
# Name: spiser, dtype: int64

# %%
tuples_second.loc['spiser']
# Out:
# as_second    42501
# Name: spiser, dtype: int64

# %%
def pmi_series(df = None, tuples_second = None, word = None, cutoff = 1):

    # conditional probabilities in series
    series = (df.loc[word]/df.loc[word].sum())['freq']
    second_series = df.loc[word]
    # divided by general probabilites (not normalized!!)
    return second_series['freq']/pd.Series([tuples_second.loc[x].values[0] for x in second_series.index], index = second_series.index)

# %% [markdown]
# ## A

# %%
a = pmi_series(df = coord, tuples_second = tuples_second, word = "diktatur", cutoff = 0).sort_values(ascending = False).head(50)

# %%
res = pd.DataFrame()
i = 0
for word in galaxy_freqs.index:
    i += 1
    if i % 100000 == 0:
        print('antall ord', i)
    if galaxy_freqs.loc["word"].as_first > 0:
        s = pd.DataFrame(pmi_series(df = coord, tuples_second = tuples_second, word = word, cutoff = 0), columns = ['pmi'])
        s.index = pd.MultiIndex.from_tuples([(word, i) for i in s.index], names = ['first', 'second'])
        res = pd.concat([res, pd.DataFrame(s)])

# %%
res.merge(coord, left_index = True, right_index = True)

# %%
res.to_csv('galaxy_books.csv')

# %%
c['relative'] = (c/c.sum())['freq']

# %%
#pd.Series([tuples_second.loc[x].values[0] for x in c.index], index = c.index)

# %%
c['score'] = c.freq*c.pmi

# %%
c.sort_values(by = "score", ascending = False).head(50)
# Out:
#                 freq       pmi      score  relative
# second
# masseaktionen     13  1.000000  13.000000  0.011404
# masseaksjonen     11  0.458333   5.041667  0.009649
# sovjetmakten       7  0.500000   3.500000  0.006140
# demokrati        260  0.010727   2.788894  0.228070
# tyranni           24  0.048780   1.170732  0.021053
# undertrykkelse    79  0.009406   0.743065  0.069298
# terror            61  0.011540   0.703935  0.053509
# ensretting        13  0.043919   0.570946  0.011404
# klassekampen       7  0.057377   0.401639  0.006140
# fascisme          19  0.011269   0.214116  0.016667
# proletariatets    12  0.017467   0.209607  0.010526
# partiets          12  0.014235   0.170819  0.010526
# revolusjon        17  0.005057   0.085961  0.014912
# ufrihet            8  0.007859   0.062868  0.007018
# sosialismen        9  0.006647   0.059823  0.007895
# diktning          18  0.001863   0.033537  0.015789
# vold              25  0.000942   0.023547  0.021930
# krig              17  0.000827   0.014053  0.014912
# utviklinga         4  0.002500   0.010000  0.003509
# tvang             20  0.000364   0.007284  0.017544
# undertrykking      4  0.001558   0.006231  0.003509
# det               94  0.000043   0.004064  0.082456
# en               112  0.000033   0.003746  0.098246
# dets              20  0.000172   0.003447  0.017544
# den               75  0.000036   0.002696  0.065789
# skaper             6  0.000254   0.001527  0.005263
# et                37  0.000032   0.001180  0.032456
# økonomisk         12  0.000097   0.001160  0.010526
# frihet             5  0.000137   0.000686  0.004386
# om                18  0.000031   0.000552  0.015789
# for               23  0.000021   0.000472  0.020175
# ble               17  0.000019   0.000325  0.014912
# under              5  0.000032   0.000159  0.004386
# ikke              15  0.000010   0.000154  0.013158
# vil                6  0.000024   0.000144  0.005263
# dermed             6  0.000020   0.000123  0.005263
# at                10  0.000009   0.000094  0.008772
# er                 8  0.000008   0.000063  0.007018
# de                11  0.000005   0.000058  0.009649
# i                 12  0.000004   0.000051  0.010526
# til                8  0.000003   0.000025  0.007018

# %%
coord.loc['sitter'].sort_values(by = 'freq')
# Out:
#           freq
# second
# googler      5
# nyder        5
# vender       5
# knar         5
# bæsj         5
# ...        ...
# leser     5096
# tenker    5681
# skriver   6023
# venter    9541
# ser      15629
#
# [678 rows x 1 columns]

# %%
series = (coord.loc['spiser']/coord.loc['spiser'].sum())['freq']

# %%
second_series = coord.loc['spiser']
second_series['freq']
# Out:
# second
# Eleseus        8
# andre         10
# arbeider      54
# at            52
# av            10
#             ...
# vi            47
# vil           11
# vokser       159
# å              6
# ødelegger     20
# Name: freq, Length: 137, dtype: int64

# %%
coord.loc['spiser'].sort_values(by = 'freq', ascending = False).head(30)
# Out:
#          freq
# second
# drikker  9341
# sover    1681
# spiser    691
# hvordan   364
# hvor      312
# lever     297
# snakker   248
# koser     221
# blir      217
# hva       180
# ikke      178
# prater    175
# vokser    159
# ser       157
# når       149
# går       145
# er        119
# har       108
# det       101
# hviler     95
# tar        87
# legger     80
# gjør       80
# jeg        78
# hygger     71
# ler        67
# de         64
# så         64
# den        64
# bor        62

# %%
pd.Series([tuples_second.loc[x].values[0] for x in second_series.index], index = second_series.index).sort_values(ascending = False).head(30)
# Out:
# second
# med        3601726
# så         3034962
# i          2809784
# til        2589892
# det        2174440
# de         2104022
# den        2086177
# andre      1713435
# ikke       1463778
# jeg        1456740
# for        1119999
# at         1067333
# som        1064605
# er         1014549
# på         1000415
# har         955633
# se          730018
# om          586914
# ser         521481
# kan         484861
# han         445739
# blir        360262
# går         339951
# å           312099
# etter       304255
# hvordan     301701
# hva         299967
# dermed      293198
# av          285535
# hvor        270729
# dtype: int64

# %%
(second_series['freq']/pd.Series([tuples_second.loc[x].values[0] for x in second_series.index], index = second_series.index)).sort_values(ascending = False).head(30)
# Out:
# second
# fordøyer              0.294798
# drikker               0.206089
# puler                 0.161290
# hjertekarsykdommer    0.137255
# hygger                0.110420
# driter                0.108225
# overnatter            0.089431
# kvitrer               0.085470
# Eleseus               0.072072
# bæsjer                0.066667
# koser                 0.060565
# sover                 0.058324
# gotter                0.038462
# smatter               0.023739
# spiser                0.016258
# småprater             0.014925
# kler                  0.012417
# nyter                 0.011162
# vokser                0.010851
# hviler                0.010793
# prater                0.010160
# lever                 0.008963
# tygger                0.008696
# trener                0.008538
# spyr                  0.007194
# oppholder             0.006933
# slapper               0.005076
# nynner                0.004892
# kroppens              0.004449
# formerer              0.004269
# dtype: float64

# %%
series
# Out:
# second
# Eleseus      0.000456
# andre        0.000570
# arbeider     0.003077
# at           0.002963
# av           0.000570
#                ...
# vi           0.002678
# vil          0.000627
# vokser       0.009059
# å            0.000342
# ødelegger    0.001139
# Name: freq, Length: 137, dtype: float64

# %%
coord.loc['A']['pmi']  = pmi_series('A')

# %%
coord.loc['A']
# Out:
#          freq
# second
# A        2052
# AA         25
# AB        598
# AC          8
# AN          5
# ...       ...
# én         99
# ø          14
# øienafd     5
# øk         15
# øvrige      7
#
# [861 rows x 1 columns]

# %%
pmi_series('abort').sort_values(ascending = False).head(30)
# Out:
# second
# prevensjon           9400.898033
# for                  5409.639570
# eutanasi             3661.402392
# homofili             2869.747821
# sterilisering        2770.790999
# fødsel               2605.862964
# en                   2473.920535
# skilsmisse           2374.963714
# dødfødsel            1913.165214
# dødshjelp            1781.222785
# seksuelt             1715.251571
# fosterdiagnostikk    1682.265964
# andre                1682.265964
# provosert            1649.280357
# homoseksualitet      1550.323535
# som                  1484.352321
# det                  1451.366714
# fosterteknologi      1385.395500
# om                   1352.409893
# mot                  1352.409893
# prostitusjon         1187.481857
# at                   1121.510643
# den                  1121.510643
# barnedrap            1055.539428
# aktiv                 989.568214
# intrauterin           956.582607
# ikke                  824.640178
# å                     824.640178
# i                     791.654571
# de                    791.654571
# Name: freq, dtype: float64

# %%
coord.loc['abort']['freq'].sort_values(ascending = False).head(30)
# Out:
# second
# prevensjon           285
# for                  164
# eutanasi             111
# homofili              87
# sterilisering         84
# fødsel                79
# en                    75
# skilsmisse            72
# dødfødsel             58
# dødshjelp             54
# seksuelt              52
# fosterdiagnostikk     51
# andre                 51
# provosert             50
# homoseksualitet       47
# som                   45
# det                   44
# fosterteknologi       42
# om                    41
# mot                   41
# prostitusjon          36
# at                    34
# den                   34
# barnedrap             32
# aktiv                 30
# intrauterin           29
# ikke                  25
# å                     25
# i                     24
# de                    24
# Name: freq, dtype: int64

# %%
cond2('drikker').sort_values(by = 'freq', ascending = False).head(20)
# Out:
#              freq
# second
# spiser   0.081893
# drikker  0.081610
# røyker   0.056673
# er       0.041513
# spiller  0.038254
# snakker  0.028903
# sover    0.028762
# prater   0.028053
# danser   0.027345
# har      0.024795
# blir     0.020261
# ikke     0.019127
# ser      0.018135
# ler      0.016435
# slåss    0.014735
# hvor     0.013460
# fester   0.013177
# synger   0.012751
# de       0.012326
# setter   0.012326

# %%
coord.xs('drikker', level = 0).sort_values(by = "freq", ascending = False).head(20)
# Out:
#          freq
# second
# spiser    578
# drikker   576
# røyker    400
# er        293
# spiller   270
# snakker   204
# sover     203
# prater    198
# danser    193
# har       175
# blir      143
# ikke      135
# ser       128
# ler       116
# slåss     104
# hvor       95
# fester     93
# synger     90
# de         87
# setter     87

# %%
coord.loc["smør"].sort_values(by = 'freq', ascending = False).head(50)
# Out:
#              freq
# second
# ost         15519
# sukker      10167
# mel          4132
# brød         2679
# olje         2647
# margarin     2272
# egg          1903
# en           1750
# melk         1497
# fløte        1462
# syltetøy     1345
# pålegg       1205
# salt         1063
# litt         1035
# honning       917
# andre         842
# sirup         841
# kjøtt         835
# et            823
# mjøl          806
# melis         743
# marmelade     654
# flatbrød      565
# legg          560
# poteter       529
# flesk         514
# la            511
# rør           510
# olivenolje    482
# dryss         479
# smak          459
# ha            459
# hvetemel      450
# stek          417
# sjokolade     404
# ingen         399
# tilsett       391
# brunost       389
# garneres      384
# vann          380
# fisk          372
# krydder       366
# rømme         358
# kaffe         348
# mjølk         344
# persille      337
# i             336
# korn          333
# ikke          319
# revet         301

# %%
def make_graph(word):
    seconds = coord.loc["
