# %% [markdown]
# # Creating graphs
#
# From a csv file with at least three columns, two with words and one with a frequency.

# %%
import sqlite3
import pandas as pd
import networkx as nx
import dhlab.graph_networkx_louvain as gnl

# %% [markdown]
# # Functions

# %%
def query(db, sql, param=()):
    """ Query a sqlitedatabase with sql and param"""
    with sqlite3.connect(db) as con:
        cur = con.cursor()
        cur.execute(sql, param)
    return cur.fetchall()

# %%
def check_graph_first(db, x, top = 20):
    return query(db, "select * from word_graph where first = ? order by pmi desc limit ?", (x, top))
def check_graph_second(db, x, top = 20):
    return query(db, "select * from word_graph where second = ? order by pmi desc limit ?", (x, top))

# %% [markdown]
# # Querying word graphs
#
# The table of word pairs is computed using the ngram-table and named word_graph. Indexed and ready to use.
#
# The columns of the word_graph table are first, second, freq, pmi where freq contains the original frequencies, and pmi is the computed association value, using the following formula:
#
# $$\frac{\textrm{freq}(x,y)^2}{\textrm{freq}(x)*\textrm{freq}(y)}$$
#
# The frequency is squared to give the cooccurence frequency a higher weight. The marginals freq(x) are aggregated from the word positions. For each word  𝑤  it is associated with two frequencies, one frequency from the occurence in the first column, and one from the second column.

# %%
word_graphs = "book_news_word_pairs.db"

# %%
def expand(db, x, top = 30):
    a = check_graph_first(db, x, top)
    b = check_graph_second(db, x, top)
    words = {x[1] for x in a} | {x[0] for x in b} - {x}
    G = a + b
    for word in words:
        G += check_graph_first(db, word, top) + check_graph_second(db, word, top)
    return G

# %%
edges = [tuple(x[:3]) for x in expand(word_graphs, "demokrati", top = 20)]

# %%
edges = [tuple(x[:3]) for x in expand(word_graphs, "demokrati", top = 20)]
g = nx.DiGraph()
g.add_weighted_edges_from(edges)
g = g.subgraph([n for n,d in g.out_degree() if d > 0])
gnl.show_graph(g, spread = 1.2)

# %%
gnl.show_communities(g)
# Out:
# demokrati-likeverd :  demokrati, likeverd, likestilling, Diktatur, Makt, korporativ, totalitarisme, mangfold, toleranse, kvinnekamp, kvinnesak, kvinnefrigjøring, likelønn, feminisme, Empirisme, integrering, jamstilling, Rasehat, gjensidighet, solidaritet, likerett, respekt, frigjøring, Kjønnsroller, Likeverd, wkrati, kvinnespørsmål, forankreti, Mal, Masse, Mål, Dandyer, Familiepraksis, Deliberasjon, Hemmelighold, struktur, ikrati, deltaking, ), mannsroller, Aksjoner, demokrali, Deltaking, Visdom, Føderalisme, Sex, virksomhetsorientering, religion, Likestilling, personlig, nokrati, Penger, Husholdsarbeid, kjønnsroller, Rationalitet, Bronse, Mat, Menn, okrati, Likhet, parlamentarisk, familiepolitikk
#
# rettssikkerhet-personvern :  rettssikkerhet, personvern, selvbestemmelse, likebehandling, Grunnlov, forutberegnelighet, brukerinnflytelse, Filmsensur, Effektivitet, Tvangsinnleggelse, Fullmaktslovgivning, styringsgrad, Justismord, Ressursbruk, fylkesnemnder, Rettferdighet, law, Barnevernsklager
#
# menneskerettigheter-menneskerettar :  menneskerettigheter, menneskerettar, menneskeretter, menneskeverd, folkerett, rettstryggleik, folkesuverenitet, utvikling, Menneskeverd, demokratiutvikling, nedrusting, Sivilprosess, rettsstatsprinsipper, livssyn, Naturrett, Livssynsfrihet, nedrustning, Rettergang, politikk, regler, Rettsstat, fangehistorie, -, Rettstat, flyktningspørsmål, Politikk, miljø, Diskursetikk, sivilprosess, Flyktningar, Skolefrihet, Arbeidstvistlov, Fremmedrett, Offentleglov
#
# frihet-folkestyre :  frihet, folkestyre, fred, likhet, rettferdighet, fridom, flertalsstyre, selvstendighet, forfatning, folkefrihet, trygghet, sjølstende, grunnlov, lokaldemokrati, Fred, uavhengighet, sjølvråderett, autonomi, Autoritet, fedreland, Fangenskap, sannhet, mokrati, individualitet, Personaldemokrati, Folkerøysting, folkefridom, Land, Parlamentarisme, Sjølråderett, Fylkeskraft, Morallov, bundethet, kjærlighet, Sjølvstyre, Fullmakter, Partistyre
#
# medbestemmelse-deltakelse :  medbestemmelse, deltakelse, innflytelse, eiendomsrett, bedriftsdemokrati, medinnflytelse, medansvar, nærdemokrati, medvirkning, Medvirkning, planleggingssystemer, Interesserepresentasjon, sjøl-, seiv-, medleven, Innflytelse, selvråderett, Overnasjonalisering, Medansvar, Selvbestemmelse
#
# rettsstat-parlamentarisme :  rettsstat, parlamentarisme, diktatur, medborgerskap, Demokrati, maktfordeling, revolusjon, terror, klassevelde, ensretting, humanisme, politistat, klassestyre, regjeringsmakt, kulturnasjon, ufrihet, borgerkrig, rettigheter, presidentstyre, kultur, partivesen, velferdsstat, byregjering, Riksrett, raadssystem, Maktbyte, enevelde, empowerment, komitemodellen, Rettsliv, Kultur, fylkeshovedstad, aktivitet, fremmedherredømme, fascisme, Maktfordeling, demokratiforståelse, skrekkregime, Presidentstyre, rådsforfatning, statsmakt, Barnevern, institusjoner, engasjement, arbeidsliv, Embetsmannsstat, hjem, migrasjon, Markedsreformer, livsmestring, einsretting, krati, Oppløsningsrett, flertallsvalg, samskaping, raadsforfatning, Partivesen, statsborgerskap, tvang, Menneskerettigheter, deltagelse, Topartisystem
#
# ytringsfridom-sosialisme :  ytringsfridom, sosialisme, markedsøkonomi, Sosialisme, flerpartisystem, kapitalisme, liberalisme, planøkonomi, religionsfridom, anarkisme, Kristendom, kristendom, kommunisme, trusfridom, frihandel, privatisering, marxisme, kvinnefrigjering, litteratur, kommandoøkonomi, konservatisme, åndsfridom, valg, pluralisme, pressefridom, nynazisme, statsplanøkonomi, styresett, Personvern, konstitusjonalisme, husholds-, styre, Statskapitalisme, religions-, mikroøkonomi, mikro-, folkedemokrati, organisasjons-, trus-, venstreradikalisme, meinings-, ,, Frihet, formynderstat, Kvinnefrigjøring, avisteikning, foretaks-, openheit, nasjonalisme, Liberalisme, munisme, eigedomsrett, Mikro-
#
# ytringsfrihet-religionsfrihet :  ytringsfrihet, religionsfrihet, lojalitetsplikt, trosfrihet, pressefrihet, trykkefrihet, journalistikk, forsamlingsfrihet, organisasjonsfrihet, tankefrihet, tanke-, meningsfrihet, presse-, menings-, avistegning, ungavistegning, menings, Lojalitetsplikt, trykke-
